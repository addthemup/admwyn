# %%
import requests
from bs4 import BeautifulSoup
import json
from urllib.parse import urljoin, parse_qs, urlparse

# Define the base URL for the site
base_url = "https://www.statmuse.com"

# URL of the page to scrape
url = "https://www.statmuse.com/mlb/ask?q=2024+mlb+stats+wrc%2B+leaders"

# Correct header mapping for the table
correct_headers = [
    "Rank", "Name", "wRC+", "Season", "Team", "Games Played", "At-Bats",
    "Runs", "Hits", "Doubles", "Triples", "Home Runs", "RBIs", "Walks",
    "Hit By Pitch", "Strikeouts", "Stolen Bases", "Caught Stealing",
    "Plate Appearances", "Total Bases", "Extra Base Hits", "Sac Hits",
    "Sac Flies", "Intentional Walks", "Grounded Into Double Play",
    "Batting Average", "On-Base Percentage", "Slugging Percentage", "OPS",
    "Weighted Runs Created", "Weighted Runs Above Average", "wOBA", "BRAA"
]

# Make a request to the page
response = requests.get(url)
response.raise_for_status()

# Parse the HTML content with BeautifulSoup
soup = BeautifulSoup(response.text, 'html.parser')

# Find the table rows
rows = soup.select('tbody > tr')

# Extract data from each row
data = []
for row in rows:
    try:
        # Extract player rank
        rank = row.select_one('td:nth-of-type(1)').text.strip()
        
        # Extract player image and parse the true URL
        img_tag = row.select_one('td:nth-of-type(2) img')
        img_src = None
        if img_tag:
            img_query = parse_qs(urlparse(img_tag['src']).query)
            img_src = img_query.get('href', [None])[0]
        
        # Extract player name
        name_tag = row.select_one('td:nth-of-type(3) a')
        name = name_tag.get('title', '').strip() if name_tag else "Unknown"
        
        # Extract other stats
        stat_cells = row.select('td:nth-of-type(n+4)')
        stats = {correct_headers[i + 2]: stat_cells[i].text.strip() for i in range(len(stat_cells))}

        # Append the row data
        data.append({
            "rank": rank,
            "name": name,
            "image": img_src,
            "stats": stats,
        })
    except Exception as e:
        print(f"Error processing row: {row}, error: {e}")

# Convert data to JSON
output_json = json.dumps(data, indent=4)

# Print the JSON
print(output_json)

# Save to a file
with open("wrc_plus_leaders_2024.json", "w") as file:
    file.write(output_json)
# Out:
# [
#     {
#         "rank": "1",
#         "name": "Aaron Judge",
#         "image": "https://cdn.statmuse.com/img/mlb/players/new-york-yankees-aaron-judge2022-min--6erpzlwb.png",
#         "stats": {
#             "wRC+": "219",
#             "Season": "2024",
#             "Team": "NYY",
#             "Games Played": "158",
#             "At-Bats": "559",
#             "Runs": "122",
#             "Hits": "180",
#             "Doubles": "36",
#             "Triples": "1",
#             "Home Runs": "58",
#             "RBIs": "144",
#             "Walks": "133",
#             "Hit By Pitch": "9",
#             "Strikeouts": "171",
#             "Stolen Bases": "10",
#             "Caught Stealing": "0",
#             "Plate Appearances": "703",
#             "Total Bases": "392",
#             "Extra Base Hits": "95",
#             "Sac Hits": "0",
#             "Sac Flies": "2",
#             "Intentional Walks": "20",
#             "Grounded Into Double Play": "22",
#             "Batting Average": ".322",
#             "On-Base Percentage": ".458",
#             "Slugging Percentage": ".701",
#             "OPS": "1.159",
#             "Weighted Runs Created": "176",
#             "Weighted Runs Above Average": "93.7",
#             "wOBA": ".476",
#             "BRAA": "95.5"
#         }
#     },
#     {
#         "rank": "2",
#         "name": "Shohei Ohtani",
#         "image": "https://cdn.statmuse.com/img/mlb/players/los-angeles-dodgers-shohei-ohtani-min--_fbzujfn.png",
#         "stats": {
#             "wRC+": "181",
#             "Season": "2024",
#             "Team": "LAD",
#             "Games Played": "159",
#             "At-Bats": "636",
#             "Runs": "134",
#             "Hits": "197",
#             "Doubles": "38",
#             "Triples": "7",
#             "Home Runs": "54",
#             "RBIs": "130",
#             "Walks": "81",
#             "Hit By Pitch": "6",
#             "Strikeouts": "162",
#             "Stolen Bases": "59",
#             "Caught Stealing": "4",
#             "Plate Appearances": "728",
#             "Total Bases": "411",
#             "Extra Base Hits": "99",
#             "Sac Hits": "0",
#             "Sac Flies": "5",
#             "Intentional Walks": "10",
#             "Grounded Into Double Play": "7",
#             "Batting Average": ".310",
#             "On-Base Percentage": ".390",
#             "Slugging Percentage": ".646",
#             "OPS": "1.036",
#             "Weighted Runs Created": "156",
#             "Weighted Runs Above Average": "70.5",
#             "wOBA": ".431",
#             "BRAA": "70.3"
#         }
#     },
#     {
#         "rank": "3",
#         "name": "Juan Soto",
#         "image": "https://cdn.statmuse.com/img/mlb/players/new-york-yankees-juan-soto--dalsrctk.png",
#         "stats": {
#             "wRC+": "180",
#             "Season": "2024",
#             "Team": "NYY",
#             "Games Played": "157",
#             "At-Bats": "576",
#             "Runs": "128",
#             "Hits": "166",
#             "Doubles": "31",
#             "Triples": "4",
#             "Home Runs": "41",
#             "RBIs": "109",
#             "Walks": "129",
#             "Hit By Pitch": "4",
#             "Strikeouts": "119",
#             "Stolen Bases": "7",
#             "Caught Stealing": "4",
#             "Plate Appearances": "713",
#             "Total Bases": "328",
#             "Extra Base Hits": "76",
#             "Sac Hits": "0",
#             "Sac Flies": "4",
#             "Intentional Walks": "2",
#             "Grounded Into Double Play": "10",
#             "Batting Average": ".288",
#             "On-Base Percentage": ".419",
#             "Slugging Percentage": ".569",
#             "OPS": ".989",
#             "Weighted Runs Created": "147",
#             "Weighted Runs Above Average": "63.4",
#             "wOBA": ".421",
#             "BRAA": "65.2"
#         }
#     },
#     {
#         "rank": "4",
#         "name": "Yordan Alvarez",
#         "image": "https://cdn.statmuse.com/img/mlb/players/houston-astros-yordan-alvarez-min--r7r7pgv5.png",
#         "stats": {
#             "wRC+": "167",
#             "Season": "2024",
#             "Team": "HOU",
#             "Games Played": "147",
#             "At-Bats": "552",
#             "Runs": "88",
#             "Hits": "170",
#             "Doubles": "34",
#             "Triples": "2",
#             "Home Runs": "35",
#             "RBIs": "86",
#             "Walks": "69",
#             "Hit By Pitch": "10",
#             "Strikeouts": "95",
#             "Stolen Bases": "6",
#             "Caught Stealing": "0",
#             "Plate Appearances": "635",
#             "Total Bases": "313",
#             "Extra Base Hits": "71",
#             "Sac Hits": "0",
#             "Sac Flies": "4",
#             "Intentional Walks": "16",
#             "Grounded Into Double Play": "14",
#             "Batting Average": ".308",
#             "On-Base Percentage": ".392",
#             "Slugging Percentage": ".567",
#             "OPS": ".959",
#             "Weighted Runs Created": "121",
#             "Weighted Runs Above Average": "46.7",
#             "wOBA": ".402",
#             "BRAA": "49.1"
#         }
#     },
#     {
#         "rank": "5",
#         "name": "Bobby Witt Jr.",
#         "image": "https://cdn.statmuse.com/img/mlb/players/kansas-city-royals-bobby-witt-jr-copy-min--1k6t2ycj.png",
#         "stats": {
#             "wRC+": "167",
#             "Season": "2024",
#             "Team": "KCR",
#             "Games Played": "161",
#             "At-Bats": "636",
#             "Runs": "125",
#             "Hits": "211",
#             "Doubles": "45",
#             "Triples": "11",
#             "Home Runs": "32",
#             "RBIs": "109",
#             "Walks": "57",
#             "Hit By Pitch": "8",
#             "Strikeouts": "106",
#             "Stolen Bases": "31",
#             "Caught Stealing": "12",
#             "Plate Appearances": "709",
#             "Total Bases": "374",
#             "Extra Base Hits": "88",
#             "Sac Hits": "0",
#             "Sac Flies": "8",
#             "Intentional Walks": "9",
#             "Grounded Into Double Play": "4",
#             "Batting Average": ".332",
#             "On-Base Percentage": ".389",
#             "Slugging Percentage": ".588",
#             "OPS": ".977",
#             "Weighted Runs Created": "140",
#             "Weighted Runs Above Average": "56.8",
#             "wOBA": ".410",
#             "BRAA": "54.5"
#         }
#     },
#     {
#         "rank": "6",
#         "name": "Vladimir Guerrero Jr.",
#         "image": "https://cdn.statmuse.com/img/mlb/players/toronto-blue-jays-vladimir-guerrero-jr2024--sqchxx63.png",
#         "stats": {
#             "wRC+": "165",
#             "Season": "2024",
#             "Team": "TOR",
#             "Games Played": "159",
#             "At-Bats": "616",
#             "Runs": "98",
#             "Hits": "199",
#             "Doubles": "44",
#             "Triples": "1",
#             "Home Runs": "30",
#             "RBIs": "103",
#             "Walks": "72",
#             "Hit By Pitch": "5",
#             "Strikeouts": "96",
#             "Stolen Bases": "2",
#             "Caught Stealing": "2",
#             "Plate Appearances": "697",
#             "Total Bases": "335",
#             "Extra Base Hits": "75",
#             "Sac Hits": "0",
#             "Sac Flies": "4",
#             "Intentional Walks": "12",
#             "Grounded Into Double Play": "16",
#             "Batting Average": ".323",
#             "On-Base Percentage": ".396",
#             "Slugging Percentage": ".544",
#             "OPS": ".940",
#             "Weighted Runs Created": "131",
#             "Weighted Runs Above Average": "49.2",
#             "wOBA": ".398",
#             "BRAA": "51.8"
#         }
#     },
#     {
#         "rank": "7",
#         "name": "Brent Rooker",
#         "image": "https://cdn.statmuse.com/img/mlb/players/oakland-athletics-silhouette--ajystimn.png",
#         "stats": {
#             "wRC+": "164",
#             "Season": "2024",
#             "Team": "OAK",
#             "Games Played": "145",
#             "At-Bats": "546",
#             "Runs": "82",
#             "Hits": "160",
#             "Doubles": "26",
#             "Triples": "2",
#             "Home Runs": "39",
#             "RBIs": "112",
#             "Walks": "59",
#             "Hit By Pitch": "5",
#             "Strikeouts": "177",
#             "Stolen Bases": "11",
#             "Caught Stealing": "3",
#             "Plate Appearances": "614",
#             "Total Bases": "307",
#             "Extra Base Hits": "67",
#             "Sac Hits": "0",
#             "Sac Flies": "4",
#             "Intentional Walks": "4",
#             "Grounded Into Double Play": "5",
#             "Batting Average": ".293",
#             "On-Base Percentage": ".365",
#             "Slugging Percentage": ".562",
#             "OPS": ".927",
#             "Weighted Runs Created": "112",
#             "Weighted Runs Above Average": "40.5",
#             "wOBA": ".392",
#             "BRAA": "45"
#         }
#     },
#     {
#         "rank": "8",
#         "name": "Gunnar Henderson",
#         "image": "https://cdn.statmuse.com/img/mlb/players/baltimore-orioles-gunnar-henderson24--d1enoem3.png",
#         "stats": {
#             "wRC+": "154",
#             "Season": "2024",
#             "Team": "BAL",
#             "Games Played": "159",
#             "At-Bats": "630",
#             "Runs": "118",
#             "Hits": "177",
#             "Doubles": "31",
#             "Triples": "7",
#             "Home Runs": "37",
#             "RBIs": "92",
#             "Walks": "78",
#             "Hit By Pitch": "7",
#             "Strikeouts": "159",
#             "Stolen Bases": "21",
#             "Caught Stealing": "4",
#             "Plate Appearances": "719",
#             "Total Bases": "333",
#             "Extra Base Hits": "75",
#             "Sac Hits": "0",
#             "Sac Flies": "4",
#             "Intentional Walks": "1",
#             "Grounded Into Double Play": "2",
#             "Batting Average": ".281",
#             "On-Base Percentage": ".364",
#             "Slugging Percentage": ".529",
#             "OPS": ".893",
#             "Weighted Runs Created": "125",
#             "Weighted Runs Above Average": "41.2",
#             "wOBA": ".381",
#             "BRAA": "44.8"
#         }
#     },
#     {
#         "rank": "9",
#         "name": "Marcell Ozuna",
#         "image": "https://cdn.statmuse.com/img/mlb/players/atlanta-braves-marcell-ozuna-min--klhix-kq.png",
#         "stats": {
#             "wRC+": "154",
#             "Season": "2024",
#             "Team": "ATL",
#             "Games Played": "162",
#             "At-Bats": "606",
#             "Runs": "96",
#             "Hits": "183",
#             "Doubles": "31",
#             "Triples": "0",
#             "Home Runs": "39",
#             "RBIs": "104",
#             "Walks": "74",
#             "Hit By Pitch": "3",
#             "Strikeouts": "170",
#             "Stolen Bases": "1",
#             "Caught Stealing": "0",
#             "Plate Appearances": "687",
#             "Total Bases": "331",
#             "Extra Base Hits": "70",
#             "Sac Hits": "0",
#             "Sac Flies": "4",
#             "Intentional Walks": "2",
#             "Grounded Into Double Play": "23",
#             "Batting Average": ".302",
#             "On-Base Percentage": ".378",
#             "Slugging Percentage": ".546",
#             "OPS": ".925",
#             "Weighted Runs Created": "127",
#             "Weighted Runs Above Average": "46.6",
#             "wOBA": ".395",
#             "BRAA": "44"
#         }
#     },
#     {
#         "rank": "10",
#         "name": "Ketel Marte",
#         "image": "https://cdn.statmuse.com/img/mlb/players/arizona-diamondbacks-ketel-marte2023--xqhdeks7.png",
#         "stats": {
#             "wRC+": "151",
#             "Season": "2024",
#             "Team": "ARI",
#             "Games Played": "136",
#             "At-Bats": "504",
#             "Runs": "93",
#             "Hits": "147",
#             "Doubles": "23",
#             "Triples": "2",
#             "Home Runs": "36",
#             "RBIs": "95",
#             "Walks": "65",
#             "Hit By Pitch": "5",
#             "Strikeouts": "106",
#             "Stolen Bases": "7",
#             "Caught Stealing": "1",
#             "Plate Appearances": "583",
#             "Total Bases": "282",
#             "Extra Base Hits": "61",
#             "Sac Hits": "0",
#             "Sac Flies": "9",
#             "Intentional Walks": "7",
#             "Grounded Into Double Play": "9",
#             "Batting Average": ".292",
#             "On-Base Percentage": ".372",
#             "Slugging Percentage": ".560",
#             "OPS": ".932",
#             "Weighted Runs Created": "106",
#             "Weighted Runs Above Average": "37.9",
#             "wOBA": ".391",
#             "BRAA": "35.7"
#         }
#     },
#     {
#         "rank": "11",
#         "name": "Bryce Harper",
#         "image": "https://cdn.statmuse.com/img/mlb/players/philadelphia-phillies-bryce-harper2022-min--tmdlkdiy.png",
#         "stats": {
#             "wRC+": "145",
#             "Season": "2024",
#             "Team": "PHI",
#             "Games Played": "145",
#             "At-Bats": "550",
#             "Runs": "85",
#             "Hits": "157",
#             "Doubles": "42",
#             "Triples": "0",
#             "Home Runs": "30",
#             "RBIs": "87",
#             "Walks": "76",
#             "Hit By Pitch": "2",
#             "Strikeouts": "138",
#             "Stolen Bases": "7",
#             "Caught Stealing": "4",
#             "Plate Appearances": "631",
#             "Total Bases": "289",
#             "Extra Base Hits": "72",
#             "Sac Hits": "1",
#             "Sac Flies": "2",
#             "Intentional Walks": "11",
#             "Grounded Into Double Play": "18",
#             "Batting Average": ".285",
#             "On-Base Percentage": ".373",
#             "Slugging Percentage": ".525",
#             "OPS": ".898",
#             "Weighted Runs Created": "109",
#             "Weighted Runs Above Average": "35.6",
#             "wOBA": ".380",
#             "BRAA": "33.9"
#         }
#     },
#     {
#         "rank": "12",
#         "name": "Jos\u00c3\u00a9 Ram\u00c3\u00adrez",
#         "image": "https://cdn.statmuse.com/img/mlb/players/cleveland-guardians-jose-ramirez-min--rmwglym8.png",
#         "stats": {
#             "wRC+": "141",
#             "Season": "2024",
#             "Team": "CLE",
#             "Games Played": "158",
#             "At-Bats": "620",
#             "Runs": "114",
#             "Hits": "173",
#             "Doubles": "39",
#             "Triples": "2",
#             "Home Runs": "39",
#             "RBIs": "118",
#             "Walks": "54",
#             "Hit By Pitch": "1",
#             "Strikeouts": "82",
#             "Stolen Bases": "41",
#             "Caught Stealing": "7",
#             "Plate Appearances": "681",
#             "Total Bases": "333",
#             "Extra Base Hits": "80",
#             "Sac Hits": "0",
#             "Sac Flies": "6",
#             "Intentional Walks": "12",
#             "Grounded Into Double Play": "9",
#             "Batting Average": ".279",
#             "On-Base Percentage": ".335",
#             "Slugging Percentage": ".537",
#             "OPS": ".872",
#             "Weighted Runs Created": "109",
#             "Weighted Runs Above Average": "29.6",
#             "wOBA": ".364",
#             "BRAA": "32.2"
#         }
#     },
#     {
#         "rank": "13",
#         "name": "Mookie Betts",
#         "image": "https://cdn.statmuse.com/img/mlb/players/los-angeles-dodgers-mookie-betts2022-png-sb-30200f73-btenjs-min--vendsbml.png",
#         "stats": {
#             "wRC+": "141",
#             "Season": "2024",
#             "Team": "LAD",
#             "Games Played": "116",
#             "At-Bats": "450",
#             "Runs": "75",
#             "Hits": "130",
#             "Doubles": "24",
#             "Triples": "5",
#             "Home Runs": "19",
#             "RBIs": "75",
#             "Walks": "61",
#             "Hit By Pitch": "1",
#             "Strikeouts": "57",
#             "Stolen Bases": "16",
#             "Caught Stealing": "2",
#             "Plate Appearances": "516",
#             "Total Bases": "221",
#             "Extra Base Hits": "48",
#             "Sac Hits": "0",
#             "Sac Flies": "4",
#             "Intentional Walks": "2",
#             "Grounded Into Double Play": "10",
#             "Batting Average": ".289",
#             "On-Base Percentage": ".372",
#             "Slugging Percentage": ".491",
#             "OPS": ".863",
#             "Weighted Runs Created": "86",
#             "Weighted Runs Above Average": "25.2",
#             "wOBA": ".371",
#             "BRAA": "25.1"
#         }
#     },
#     {
#         "rank": "14",
#         "name": "Corey Seager",
#         "image": "https://cdn.statmuse.com/img/mlb/players/texas-rangers-corey-seager-min--eb0ehcuj.png",
#         "stats": {
#             "wRC+": "141",
#             "Season": "2024",
#             "Team": "TEX",
#             "Games Played": "123",
#             "At-Bats": "475",
#             "Runs": "68",
#             "Hits": "132",
#             "Doubles": "21",
#             "Triples": "0",
#             "Home Runs": "30",
#             "RBIs": "74",
#             "Walks": "53",
#             "Hit By Pitch": "3",
#             "Strikeouts": "96",
#             "Stolen Bases": "1",
#             "Caught Stealing": "1",
#             "Plate Appearances": "533",
#             "Total Bases": "243",
#             "Extra Base Hits": "51",
#             "Sac Hits": "0",
#             "Sac Flies": "2",
#             "Intentional Walks": "11",
#             "Grounded Into Double Play": "8",
#             "Batting Average": ".278",
#             "On-Base Percentage": ".353",
#             "Slugging Percentage": ".512",
#             "OPS": ".864",
#             "Weighted Runs Created": "86",
#             "Weighted Runs Above Average": "23.4",
#             "wOBA": ".365",
#             "BRAA": "24.7"
#         }
#     },
#     {
#         "rank": "15",
#         "name": "Jurickson Profar",
#         "image": "https://cdn.statmuse.com/img/mlb/players/generic-white-silhouette--jwj5jtmy.png",
#         "stats": {
#             "wRC+": "139",
#             "Season": "2024",
#             "Team": "SDP",
#             "Games Played": "158",
#             "At-Bats": "564",
#             "Runs": "94",
#             "Hits": "158",
#             "Doubles": "29",
#             "Triples": "0",
#             "Home Runs": "24",
#             "RBIs": "85",
#             "Walks": "76",
#             "Hit By Pitch": "18",
#             "Strikeouts": "101",
#             "Stolen Bases": "10",
#             "Caught Stealing": "3",
#             "Plate Appearances": "668",
#             "Total Bases": "259",
#             "Extra Base Hits": "53",
#             "Sac Hits": "5",
#             "Sac Flies": "5",
#             "Intentional Walks": "4",
#             "Grounded Into Double Play": "14",
#             "Batting Average": ".280",
#             "On-Base Percentage": ".380",
#             "Slugging Percentage": ".459",
#             "OPS": ".839",
#             "Weighted Runs Created": "108",
#             "Weighted Runs Above Average": "29.6",
#             "wOBA": ".365",
#             "BRAA": "31"
#         }
#     },
#     {
#         "rank": "16",
#         "name": "Seiya Suzuki",
#         "image": "https://cdn.statmuse.com/img/mlb/players/chicago-cubs-seiya-suzuki-min--99mkcnli.png",
#         "stats": {
#             "wRC+": "138",
#             "Season": "2024",
#             "Team": "CHC",
#             "Games Played": "132",
#             "At-Bats": "512",
#             "Runs": "74",
#             "Hits": "145",
#             "Doubles": "27",
#             "Triples": "6",
#             "Home Runs": "21",
#             "RBIs": "73",
#             "Walks": "63",
#             "Hit By Pitch": "6",
#             "Strikeouts": "160",
#             "Stolen Bases": "16",
#             "Caught Stealing": "6",
#             "Plate Appearances": "585",
#             "Total Bases": "247",
#             "Extra Base Hits": "54",
#             "Sac Hits": "0",
#             "Sac Flies": "4",
#             "Intentional Walks": "3",
#             "Grounded Into Double Play": "6",
#             "Batting Average": ".283",
#             "On-Base Percentage": ".366",
#             "Slugging Percentage": ".482",
#             "OPS": ".848",
#             "Weighted Runs Created": "94",
#             "Weighted Runs Above Average": "25.7",
#             "wOBA": ".365",
#             "BRAA": "26.3"
#         }
#     },
#     {
#         "rank": "17",
#         "name": "Francisco Lindor",
#         "image": "https://cdn.statmuse.com/img/mlb/players/new-york-mets-francisco-lindor2022-min--nm12aloo.png",
#         "stats": {
#             "wRC+": "137",
#             "Season": "2024",
#             "Team": "NYM",
#             "Games Played": "152",
#             "At-Bats": "618",
#             "Runs": "107",
#             "Hits": "169",
#             "Doubles": "39",
#             "Triples": "1",
#             "Home Runs": "33",
#             "RBIs": "91",
#             "Walks": "56",
#             "Hit By Pitch": "12",
#             "Strikeouts": "127",
#             "Stolen Bases": "29",
#             "Caught Stealing": "4",
#             "Plate Appearances": "689",
#             "Total Bases": "309",
#             "Extra Base Hits": "73",
#             "Sac Hits": "0",
#             "Sac Flies": "3",
#             "Intentional Walks": "0",
#             "Grounded Into Double Play": "7",
#             "Batting Average": ".273",
#             "On-Base Percentage": ".344",
#             "Slugging Percentage": ".500",
#             "OPS": ".844",
#             "Weighted Runs Created": "110",
#             "Weighted Runs Above Average": "29.2",
#             "wOBA": ".363",
#             "BRAA": "30.7"
#         }
#     },
#     {
#         "rank": "18",
#         "name": "Freddie Freeman",
#         "image": "https://cdn.statmuse.com/img/mlb/players/los-angeles-dodgers-freddie-freeman2022-min--mjzjhexa.png",
#         "stats": {
#             "wRC+": "137",
#             "Season": "2024",
#             "Team": "LAD",
#             "Games Played": "147",
#             "At-Bats": "542",
#             "Runs": "81",
#             "Hits": "153",
#             "Doubles": "35",
#             "Triples": "2",
#             "Home Runs": "22",
#             "RBIs": "89",
#             "Walks": "78",
#             "Hit By Pitch": "10",
#             "Strikeouts": "100",
#             "Stolen Bases": "9",
#             "Caught Stealing": "2",
#             "Plate Appearances": "638",
#             "Total Bases": "258",
#             "Extra Base Hits": "59",
#             "Sac Hits": "0",
#             "Sac Flies": "8",
#             "Intentional Walks": "9",
#             "Grounded Into Double Play": "13",
#             "Batting Average": ".282",
#             "On-Base Percentage": ".378",
#             "Slugging Percentage": ".476",
#             "OPS": ".854",
#             "Weighted Runs Created": "103",
#             "Weighted Runs Above Average": "28.3",
#             "wOBA": ".365",
#             "BRAA": "28.2"
#         }
#     },
#     {
#         "rank": "19",
#         "name": "Kyle Schwarber",
#         "image": "https://cdn.statmuse.com/img/mlb/players/philadelphia-phillies-kyle-schwarber2022-min--oswqm8sq.png",
#         "stats": {
#             "wRC+": "135",
#             "Season": "2024",
#             "Team": "PHI",
#             "Games Played": "150",
#             "At-Bats": "573",
#             "Runs": "110",
#             "Hits": "142",
#             "Doubles": "22",
#             "Triples": "0",
#             "Home Runs": "38",
#             "RBIs": "104",
#             "Walks": "106",
#             "Hit By Pitch": "5",
#             "Strikeouts": "197",
#             "Stolen Bases": "5",
#             "Caught Stealing": "3",
#             "Plate Appearances": "692",
#             "Total Bases": "278",
#             "Extra Base Hits": "60",
#             "Sac Hits": "0",
#             "Sac Flies": "8",
#             "Intentional Walks": "4",
#             "Grounded Into Double Play": "6",
#             "Batting Average": ".248",
#             "On-Base Percentage": ".366",
#             "Slugging Percentage": ".485",
#             "OPS": ".851",
#             "Weighted Runs Created": "112",
#             "Weighted Runs Above Average": "31",
#             "wOBA": ".366",
#             "BRAA": "29.2"
#         }
#     },
#     {
#         "rank": "20",
#         "name": "Riley Greene",
#         "image": "https://cdn.statmuse.com/img/mlb/players/detroit-tigers-riley-greene-copy-min--fnjwk7al.png",
#         "stats": {
#             "wRC+": "135",
#             "Season": "2024",
#             "Team": "DET",
#             "Games Played": "137",
#             "At-Bats": "512",
#             "Runs": "82",
#             "Hits": "134",
#             "Doubles": "27",
#             "Triples": "6",
#             "Home Runs": "24",
#             "RBIs": "74",
#             "Walks": "64",
#             "Hit By Pitch": "5",
#             "Strikeouts": "156",
#             "Stolen Bases": "4",
#             "Caught Stealing": "2",
#             "Plate Appearances": "583",
#             "Total Bases": "245",
#             "Extra Base Hits": "57",
#             "Sac Hits": "0",
#             "Sac Flies": "2",
#             "Intentional Walks": "3",
#             "Grounded Into Double Play": "2",
#             "Batting Average": ".262",
#             "On-Base Percentage": ".348",
#             "Slugging Percentage": ".479",
#             "OPS": ".827",
#             "Weighted Runs Created": "89",
#             "Weighted Runs Above Average": "21.2",
#             "wOBA": ".355",
#             "BRAA": "23.4"
#         }
#     },
#     {
#         "rank": "21",
#         "name": "Rafael Devers",
#         "image": "https://cdn.statmuse.com/img/mlb/players/boston-red-sox-rafael-devers-min--olkk8x4m.png",
#         "stats": {
#             "wRC+": "134",
#             "Season": "2024",
#             "Team": "BOS",
#             "Games Played": "138",
#             "At-Bats": "525",
#             "Runs": "87",
#             "Hits": "143",
#             "Doubles": "34",
#             "Triples": "5",
#             "Home Runs": "28",
#             "RBIs": "83",
#             "Walks": "67",
#             "Hit By Pitch": "3",
#             "Strikeouts": "147",
#             "Stolen Bases": "3",
#             "Caught Stealing": "0",
#             "Plate Appearances": "601",
#             "Total Bases": "271",
#             "Extra Base Hits": "67",
#             "Sac Hits": "0",
#             "Sac Flies": "6",
#             "Intentional Walks": "14",
#             "Grounded Into Double Play": "13",
#             "Batting Average": ".272",
#             "On-Base Percentage": ".354",
#             "Slugging Percentage": ".516",
#             "OPS": ".871",
#             "Weighted Runs Created": "96",
#             "Weighted Runs Above Average": "26",
#             "wOBA": ".364",
#             "BRAA": "23.4"
#         }
#     },
#     {
#         "rank": "22",
#         "name": "Teoscar Hern\u00c3\u00a1ndez",
#         "image": "https://cdn.statmuse.com/img/mlb/players/los-angeles-dodgers-teoscar-herna-ndez--xgvq8gvr.png",
#         "stats": {
#             "wRC+": "133",
#             "Season": "2024",
#             "Team": "LAD",
#             "Games Played": "154",
#             "At-Bats": "589",
#             "Runs": "84",
#             "Hits": "160",
#             "Doubles": "32",
#             "Triples": "2",
#             "Home Runs": "33",
#             "RBIs": "99",
#             "Walks": "53",
#             "Hit By Pitch": "8",
#             "Strikeouts": "188",
#             "Stolen Bases": "12",
#             "Caught Stealing": "3",
#             "Plate Appearances": "651",
#             "Total Bases": "295",
#             "Extra Base Hits": "67",
#             "Sac Hits": "0",
#             "Sac Flies": "1",
#             "Intentional Walks": "3",
#             "Grounded Into Double Play": "7",
#             "Batting Average": ".272",
#             "On-Base Percentage": ".339",
#             "Slugging Percentage": ".501",
#             "OPS": ".840",
#             "Weighted Runs Created": "102",
#             "Weighted Runs Above Average": "26",
#             "wOBA": ".360",
#             "BRAA": "25.9"
#         }
#     },
#     {
#         "rank": "23",
#         "name": "Steven Kwan",
#         "image": "https://cdn.statmuse.com/img/mlb/players/cleveland-guardians-steven-kwan-min--trrafa1m.png",
#         "stats": {
#             "wRC+": "131",
#             "Season": "2024",
#             "Team": "CLE",
#             "Games Played": "122",
#             "At-Bats": "480",
#             "Runs": "83",
#             "Hits": "140",
#             "Doubles": "16",
#             "Triples": "3",
#             "Home Runs": "14",
#             "RBIs": "44",
#             "Walks": "53",
#             "Hit By Pitch": "5",
#             "Strikeouts": "51",
#             "Stolen Bases": "12",
#             "Caught Stealing": "5",
#             "Plate Appearances": "540",
#             "Total Bases": "204",
#             "Extra Base Hits": "33",
#             "Sac Hits": "2",
#             "Sac Flies": "0",
#             "Intentional Walks": "0",
#             "Grounded Into Double Play": "5",
#             "Batting Average": ".292",
#             "On-Base Percentage": ".368",
#             "Slugging Percentage": ".425",
#             "OPS": ".793",
#             "Weighted Runs Created": "80",
#             "Weighted Runs Above Average": "17.1",
#             "wOBA": ".349",
#             "BRAA": "19.1"
#         }
#     },
#     {
#         "rank": "24",
#         "name": "William Contreras",
#         "image": "https://cdn.statmuse.com/img/mlb/players/milwaukee-brewers-william-contreras--qu0i2qdm.png",
#         "stats": {
#             "wRC+": "130",
#             "Season": "2024",
#             "Team": "MIL",
#             "Games Played": "155",
#             "At-Bats": "595",
#             "Runs": "99",
#             "Hits": "167",
#             "Doubles": "37",
#             "Triples": "2",
#             "Home Runs": "23",
#             "RBIs": "92",
#             "Walks": "78",
#             "Hit By Pitch": "3",
#             "Strikeouts": "139",
#             "Stolen Bases": "9",
#             "Caught Stealing": "2",
#             "Plate Appearances": "679",
#             "Total Bases": "277",
#             "Extra Base Hits": "62",
#             "Sac Hits": "0",
#             "Sac Flies": "3",
#             "Intentional Walks": "5",
#             "Grounded Into Double Play": "19",
#             "Batting Average": ".281",
#             "On-Base Percentage": ".365",
#             "Slugging Percentage": ".466",
#             "OPS": ".831",
#             "Weighted Runs Created": "106",
#             "Weighted Runs Above Average": "26.5",
#             "wOBA": ".359",
#             "BRAA": "24.8"
#         }
#     },
#     {
#         "rank": "25",
#         "name": "Jackson Merrill",
#         "image": "https://cdn.statmuse.com/img/mlb/players/san-diego-padres-jackson-merrill--7k9udqzx.png",
#         "stats": {
#             "wRC+": "130",
#             "Season": "2024",
#             "Team": "SDP",
#             "Games Played": "156",
#             "At-Bats": "554",
#             "Runs": "77",
#             "Hits": "162",
#             "Doubles": "31",
#             "Triples": "6",
#             "Home Runs": "24",
#             "RBIs": "90",
#             "Walks": "29",
#             "Hit By Pitch": "1",
#             "Strikeouts": "101",
#             "Stolen Bases": "16",
#             "Caught Stealing": "3",
#             "Plate Appearances": "593",
#             "Total Bases": "277",
#             "Extra Base Hits": "61",
#             "Sac Hits": "4",
#             "Sac Flies": "5",
#             "Intentional Walks": "1",
#             "Grounded Into Double Play": "2",
#             "Batting Average": ".292",
#             "On-Base Percentage": ".326",
#             "Slugging Percentage": ".500",
#             "OPS": ".826",
#             "Weighted Runs Created": "89",
#             "Weighted Runs Above Average": "19.7",
#             "wOBA": ".352",
#             "BRAA": "21"
#         }
#     },
#     {
#         "rank": "",
#         "name": "Unknown",
#         "image": null,
#         "stats": {
#             "wRC+": "",
#             "Season": "",
#             "Team": "",
#             "Games Played": "",
#             "At-Bats": "",
#             "Runs": "",
#             "Hits": "",
#             "Doubles": "",
#             "Triples": "",
#             "Home Runs": "",
#             "RBIs": "",
#             "Walks": "",
#             "Hit By Pitch": "",
#             "Strikeouts": "",
#             "Stolen Bases": "",
#             "Caught Stealing": "",
#             "Plate Appearances": "",
#             "Total Bases": "",
#             "Extra Base Hits": "",
#             "Sac Hits": "",
#             "Sac Flies": "",
#             "Intentional Walks": "",
#             "Grounded Into Double Play": "",
#             "Batting Average": "",
#             "On-Base Percentage": "",
#             "Slugging Percentage": "",
#             "OPS": "",
#             "Weighted Runs Created": "",
#             "Weighted Runs Above Average": "",
#             "wOBA": "",
#             "BRAA": ""
#         }
#     },
#     {
#         "rank": "",
#         "name": "Unknown",
#         "image": null,
#         "stats": {
#             "wRC+": "",
#             "Season": "",
#             "Team": "",
#             "Games Played": "",
#             "At-Bats": "",
#             "Runs": "",
#             "Hits": "",
#             "Doubles": "",
#             "Triples": "",
#             "Home Runs": "",
#             "RBIs": "",
#             "Walks": "",
#             "Hit By Pitch": "",
#             "Strikeouts": "",
#             "Stolen Bases": "",
#             "Caught Stealing": "",
#             "Plate Appearances": "",
#             "Total Bases": "",
#             "Extra Base Hits": "",
#             "Sac Hits": "",
#             "Sac Flies": "",
#             "Intentional Walks": "",
#             "Grounded Into Double Play": "",
#             "Batting Average": "",
#             "On-Base Percentage": "",
#             "Slugging Percentage": "",
#             "OPS": "",
#             "Weighted Runs Created": "",
#             "Weighted Runs Above Average": "",
#             "wOBA": "",
#             "BRAA": ""
#         }
#     },
#     {
#         "rank": "",
#         "name": "Unknown",
#         "image": null,
#         "stats": {
#             "wRC+": "",
#             "Season": "",
#             "Team": "",
#             "Games Played": "",
#             "At-Bats": "",
#             "Runs": "",
#             "Hits": "",
#             "Doubles": "",
#             "Triples": "",
#             "Home Runs": "",
#             "RBIs": "",
#             "Walks": "",
#             "Hit By Pitch": "",
#             "Strikeouts": "",
#             "Stolen Bases": "",
#             "Caught Stealing": "",
#             "Plate Appearances": "",
#             "Total Bases": "",
#             "Extra Base Hits": "",
#             "Sac Hits": "",
#             "Sac Flies": "",
#             "Intentional Walks": "",
#             "Grounded Into Double Play": "",
#             "Batting Average": "",
#             "On-Base Percentage": "",
#             "Slugging Percentage": "",
#             "OPS": "",
#             "Weighted Runs Created": "",
#             "Weighted Runs Above Average": "",
#             "wOBA": "",
#             "BRAA": ""
#         }
#     },
#     {
#         "rank": "Yankees",
#         "name": "Unknown",
#         "image": null,
#         "stats": {
#             "wRC+": ".580",
#             "Season": ""
#         }
#     },
#     {
#         "rank": "Orioles",
#         "name": "Unknown",
#         "image": null,
#         "stats": {
#             "wRC+": ".562",
#             "Season": "3.0"
#         }
#     },
#     {
#         "rank": "Red Sox",
#         "name": "Unknown",
#         "image": null,
#         "stats": {
#             "wRC+": ".500",
#             "Season": "13.0"
#         }
#     },
#     {
#         "rank": "Rays",
#         "name": "Unknown",
#         "image": null,
#         "stats": {
#             "wRC+": ".494",
#             "Season": "14.0"
#         }
#     },
#     {
#         "rank": "Blue Jays",
#         "name": "Unknown",
#         "image": null,
#         "stats": {
#             "wRC+": ".457",
#             "Season": "20.0"
#         }
#     },
#     {
#         "rank": "Tue 4/29",
#         "name": "Unknown",
#         "image": "https://cdn.statmuse.com/img/mlb/players/nyy-14-12-39--qqfuvw48.png",
#         "stats": {
#             "wRC+": "BAL",
#             "Season": "6:35 PM"
#         }
#     },
#     {
#         "rank": "Mon 4/28",
#         "name": "Unknown",
#         "image": "https://cdn.statmuse.com/img/mlb/players/nyy-14-12-39--qqfuvw48.png",
#         "stats": {
#             "wRC+": "BAL",
#             "Season": "6:35 PM"
#         }
#     },
#     {
#         "rank": "Sun 4/27",
#         "name": "Unknown",
#         "image": "https://cdn.statmuse.com/img/mlb/teams/mlb_toronto_blue_jays_secondary.png",
#         "stats": {
#             "wRC+": "NYY",
#             "Season": "4:00 AM"
#         }
#     },
#     {
#         "rank": "Sat 4/26",
#         "name": "Unknown",
#         "image": "https://cdn.statmuse.com/img/mlb/teams/mlb_toronto_blue_jays_secondary.png",
#         "stats": {
#             "wRC+": "NYY",
#             "Season": "4:00 AM"
#         }
#     },
#     {
#         "rank": "Fri 4/25",
#         "name": "Unknown",
#         "image": "https://cdn.statmuse.com/img/mlb/teams/mlb_toronto_blue_jays_secondary.png",
#         "stats": {
#             "wRC+": "NYY",
#             "Season": "7:05 PM"
#         }
#     },
#     {
#         "rank": "Phillies",
#         "name": "Unknown",
#         "image": null,
#         "stats": {
#             "wRC+": ".586",
#             "Season": ""
#         }
#     },
#     {
#         "rank": "Braves",
#         "name": "Unknown",
#         "image": null,
#         "stats": {
#             "wRC+": ".549",
#             "Season": "6.0"
#         }
#     },
#     {
#         "rank": "Brewers",
#         "name": "Unknown",
#         "image": null,
#         "stats": {
#             "wRC+": ".574",
#             "Season": ""
#         }
#     },
#     {
#         "rank": "Cubs",
#         "name": "Unknown",
#         "image": null,
#         "stats": {
#             "wRC+": ".512",
#             "Season": "10.0"
#         }
#     },
#     {
#         "rank": "Dodgers",
#         "name": "Unknown",
#         "image": null,
#         "stats": {
#             "wRC+": ".605",
#             "Season": ""
#         }
#     },
#     {
#         "rank": "Padres",
#         "name": "Unknown",
#         "image": null,
#         "stats": {
#             "wRC+": ".574",
#             "Season": "5.0"
#         }
#     },
#     {
#         "rank": "Yankees",
#         "name": "Unknown",
#         "image": null,
#         "stats": {
#             "wRC+": ".580",
#             "Season": ""
#         }
#     },
#     {
#         "rank": "Orioles",
#         "name": "Unknown",
#         "image": null,
#         "stats": {
#             "wRC+": ".562",
#             "Season": "3.0"
#         }
#     },
#     {
#         "rank": "Guardians",
#         "name": "Unknown",
#         "image": null,
#         "stats": {
#             "wRC+": ".571",
#             "Season": ""
#         }
#     },
#     {
#         "rank": "Royals",
#         "name": "Unknown",
#         "image": null,
#         "stats": {
#             "wRC+": ".531",
#             "Season": "6.5"
#         }
#     },
#     {
#         "rank": "Astros",
#         "name": "Unknown",
#         "image": null,
#         "stats": {
#             "wRC+": ".547",
#             "Season": ""
#         }
#     },
#     {
#         "rank": "Mariners",
#         "name": "Unknown",
#         "image": null,
#         "stats": {
#             "wRC+": ".525",
#             "Season": "3.5"
#         }
#     },
#     {
#         "rank": "Tue 10/29",
#         "name": "Unknown",
#         "image": "https://cdn.statmuse.com/img/mlb/players/lad--nzdk-0hn.png",
#         "stats": {
#             "wRC+": "NYY",
#             "Season": "7-6"
#         }
#     },
#     {
#         "rank": "Mon 10/28",
#         "name": "Unknown",
#         "image": "https://cdn.statmuse.com/img/mlb/players/lad--nzdk-0hn.png",
#         "stats": {
#             "wRC+": "NYY",
#             "Season": "4-11"
#         }
#     },
#     {
#         "rank": "Sun 10/27",
#         "name": "Unknown",
#         "image": "https://cdn.statmuse.com/img/mlb/players/lad--nzdk-0hn.png",
#         "stats": {
#             "wRC+": "NYY",
#             "Season": "4-2"
#         }
#     },
#     {
#         "rank": "Fri 10/25",
#         "name": "Unknown",
#         "image": "https://cdn.statmuse.com/img/mlb/players/nyy-14-12-39--qqfuvw48.png",
#         "stats": {
#             "wRC+": "LAD",
#             "Season": "2-4"
#         }
#     },
#     {
#         "rank": "Thu 10/24",
#         "name": "Unknown",
#         "image": "https://cdn.statmuse.com/img/mlb/players/nyy-14-12-39--qqfuvw48.png",
#         "stats": {
#             "wRC+": "LAD",
#             "Season": "3-6"
#         }
#     },
#     {
#         "rank": "Sat 3/29",
#         "name": "Unknown",
#         "image": "https://cdn.statmuse.com/img/mlb/teams/mlb_minnesota_twins_secondary.png",
#         "stats": {
#             "wRC+": "STL",
#             "Season": "2:15 PM"
#         }
#     },
#     {
#         "rank": "Sat 3/29",
#         "name": "Unknown",
#         "image": "https://cdn.statmuse.com/img/mlb/teams/mlb_los_angeles_angels_primary.png",
#         "stats": {
#             "wRC+": "CWS",
#             "Season": "4:00 AM"
#         }
#     },
#     {
#         "rank": "Sat 3/29",
#         "name": "Unknown",
#         "image": "https://cdn.statmuse.com/img/mlb/teams/mlb_chicago_cubs_secondary.png",
#         "stats": {
#             "wRC+": "AZ",
#             "Season": "4:00 AM"
#         }
#     },
#     {
#         "rank": "Sat 3/29",
#         "name": "Unknown",
#         "image": "https://cdn.statmuse.com/img/mlb/teams/mlb_colorado_rockies_primary.png",
#         "stats": {
#             "wRC+": "TBR",
#             "Season": "4:00 AM"
#         }
#     },
#     {
#         "rank": "Sat 3/29",
#         "name": "Unknown",
#         "image": "https://cdn.statmuse.com/img/mlb/players/ball-in-glove--rpp5y95k.png",
#         "stats": {
#             "wRC+": "NYY",
#             "Season": "4:00 AM"
#         }
#     }
# ]
